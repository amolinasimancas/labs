# %%
import numpy as np

# %%
lista = [1,2,3,4,5,6,7,8,9]
arreglo_1 = np.array(lista)
arreglo_2 = np.array([1,2,3])

print(type(arreglo_1))
print(type(arreglo_2))

print(arreglo_1)
print(arreglo_2)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [1 2 3 4 5 6 7 8 9]
# [1 2 3]

# %%
matriz = [[1,2,3],[4,5,6],[7,8,9]]
matriz_1 = np.array(matriz)
print(matriz_1)
print(type(matriz_1))
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
# <class 'numpy.ndarray'>

# %%
print(matriz[0] + matriz[1])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(arreglo_1.dtype)
print(matriz_1.dtype)
# Out:
# int64
# int64

# %%
print(arreglo_1.ndim)
print(matriz_1.ndim)
# Out:
# 1
# 2
