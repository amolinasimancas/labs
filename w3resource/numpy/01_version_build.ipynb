# %% [markdown]
# ### 1. Get NumPy Version & Build Info

# %%
import numpy as np

# %% [markdown]
# Numpy Version

# %%
np.__version__
# Out:
# '2.3.1'

# %% [markdown]
# Numpy Build Info

# %%
np.show_config()
# Out:
# {
#   "Compilers": {
#     "c": {
#       "name": "gcc",
#       "linker": "ld.bfd",
#       "version": "11.2.0",
#       "commands": "/croot/numpy_and_numpy_base_1750883793662/_build_env/bin/x86_64-conda-linux-gnu-cc",
#       "args": "-march=nocona, -mtune=haswell, -ftree-vectorize, -fPIC, -fstack-protector-strong, -fno-plt, -O2, -ffunction-sections, -pipe, -isystem, /home/amolinasimancas/anaconda3/envs/notebooks/include, -fdebug-prefix-map=/croot/numpy_and_numpy_base_1750883793662/work=/usr/local/src/conda/numpy-base-2.3.1, -fdebug-prefix-map=/home/amolinasimancas/anaconda3/envs/notebooks=/usr/local/src/conda-prefix, -DNDEBUG, -D_FORTIFY_SOURCE=2, -O2, -isystem, /home/amolinasimancas/anaconda3/envs/notebooks/include",
# ...
